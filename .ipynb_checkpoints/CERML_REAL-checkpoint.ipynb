# %% [markdown]
# # Import 버전들 확인

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
import sklearn
import sys
from sklearn.model_selection import train_test_split, RandomizedSearchCV, cross_validate, RepeatedKFold
from sklearn.svm import SVR
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.preprocessing import StandardScaler
from scipy.stats import norm, randint
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import Lasso, RidgeCV 

print('Numpy Version', np.__version__)
print('Pandas Version', pd.__version__)
print('Matplotlib Version', matplotlib.__version__)
print('Scikit-Learn Version', sklearn.__version__)
print('Tensorflow Version', tf.__version__)
print('Python Version', sys.version)
# Out:
# C:\Users\dino3\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\dino3\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
# C:\Users\dino3\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\.libs\libopenblas64__v0.3.21-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"
# Numpy Version 1.23.5
# Pandas Version 1.5.3
# Matplotlib Version 3.6.3
# Scikit-Learn Version 1.2.1
# Tensorflow Version 2.12.0
# Python Version 3.11.1 (tags/v3.11.1:a7a450f, Dec  6 2022, 19:58:39) [MSC v.1934 64 bit (AMD64)]

# %%
# %matplotlib inline

# %% [markdown]
# DATA 읽어오기

# %%
raw_data = pd.read_excel('data_new/CERML_origin.xlsx')
print(raw_data)
feature_names = np.array(['Nnum', 'ed', 'Qe', 'Ecohe', 'EN', 'EA', 'I', 'rcov', 'rZ', 'Ne', 'N', 'dMN'])

print(feature_names)
# Out:
#      M      G_Cl  Nnum    ed    Qe  Ecohe    EN    EA     I  rcov    rZ  Ne  \
# 0   Mn  0.795966     4 -0.83  1.24  -0.36  1.55 -0.50  7.43  1.39  0.23   5
# 1   Fe  0.858026     4 -0.62  1.37  -3.15  1.83  0.15  7.90  1.32  0.22   6
# 2   Co  1.150586     4 -1.01  0.91  -2.81  1.88  0.66  7.88  1.26  0.21   7
# 3   Ni  1.829476     4 -1.17  0.77  -4.69  1.92  1.16  7.64  1.24  0.20   8
# 4   Cu  1.902396     4 -1.50  0.71  -2.48  1.90  1.24  7.73  1.32  0.19  10
# ..  ..       ...   ...   ...   ...    ...   ...   ...   ...   ...   ...  ..
# 70   W -2.478654     0 -0.90  1.73  -4.03  2.36  0.82  7.98  1.62  0.59   4
# 71  Os -1.067414     0 -1.17  1.14  -2.09  2.20  1.08  8.71  1.44  0.54   6
# 72  Ir -0.004404     0 -0.94  0.60  -1.82  2.20  1.56  8.97  1.41  0.53   7
# 73  Pt  1.471646     0 -1.52  0.50  -3.19  2.28  2.13  8.96  1.36  0.51   9
# 74  Au  1.570000     0 -3.33  0.50  -1.24  2.54  2.31  9.23  1.36  0.49  10
#
#      N   dMN
# 0   25  2.22
# 1   26  2.32
# 2   27  2.03
# 3   28  1.95
# 4   29  2.11
# ..  ..   ...
# 70  74  2.40
# 71  76  2.46
# 72  77  2.47
# 73  78  2.12
# 74  79  2.51
#
# [75 rows x 14 columns]
# ['Nnum' 'ed' 'Qe' 'Ecohe' 'EN' 'EA' 'I' 'rcov' 'rZ' 'Ne' 'N' 'dMN']

# %% [markdown]
# # Data preprocessing

# %%
print(raw_data)
data_cleaned = raw_data.iloc[:,2:] # input data들만 모은 array
print(data_cleaned)
# Out:
#      M      G_Cl  Nnum    ed    Qe  Ecohe    EN    EA     I  rcov    rZ  Ne  \
# 0   Mn  0.795966     4 -0.83  1.24  -0.36  1.55 -0.50  7.43  1.39  0.23   5
# 1   Fe  0.858026     4 -0.62  1.37  -3.15  1.83  0.15  7.90  1.32  0.22   6
# 2   Co  1.150586     4 -1.01  0.91  -2.81  1.88  0.66  7.88  1.26  0.21   7
# 3   Ni  1.829476     4 -1.17  0.77  -4.69  1.92  1.16  7.64  1.24  0.20   8
# 4   Cu  1.902396     4 -1.50  0.71  -2.48  1.90  1.24  7.73  1.32  0.19  10
# ..  ..       ...   ...   ...   ...    ...   ...   ...   ...   ...   ...  ..
# 70   W -2.478654     0 -0.90  1.73  -4.03  2.36  0.82  7.98  1.62  0.59   4
# 71  Os -1.067414     0 -1.17  1.14  -2.09  2.20  1.08  8.71  1.44  0.54   6
# 72  Ir -0.004404     0 -0.94  0.60  -1.82  2.20  1.56  8.97  1.41  0.53   7
# 73  Pt  1.471646     0 -1.52  0.50  -3.19  2.28  2.13  8.96  1.36  0.51   9
# 74  Au  1.570000     0 -3.33  0.50  -1.24  2.54  2.31  9.23  1.36  0.49  10
#
#      N   dMN
# 0   25  2.22
# 1   26  2.32
# 2   27  2.03
# 3   28  1.95
# 4   29  2.11
# ..  ..   ...
# 70  74  2.40
# 71  76  2.46
# 72  77  2.47
# 73  78  2.12
# 74  79  2.51
#
# [75 rows x 14 columns]
#     Nnum    ed    Qe  Ecohe    EN    EA     I  rcov    rZ  Ne   N   dMN
# 0      4 -0.83  1.24  -0.36  1.55 -0.50  7.43  1.39  0.23   5  25  2.22
# 1      4 -0.62  1.37  -3.15  1.83  0.15  7.90  1.32  0.22   6  26  2.32
# 2      4 -1.01  0.91  -2.81  1.88  0.66  7.88  1.26  0.21   7  27  2.03
# 3      4 -1.17  0.77  -4.69  1.92  1.16  7.64  1.24  0.20   8  28  1.95
# 4      4 -1.50  0.71  -2.48  1.90  1.24  7.73  1.32  0.19  10  29  2.11
# ..   ...   ...   ...    ...   ...   ...   ...   ...   ...  ..  ..   ...
# 70     0 -0.90  1.73  -4.03  2.36  0.82  7.98  1.62  0.59   4  74  2.40
# 71     0 -1.17  1.14  -2.09  2.20  1.08  8.71  1.44  0.54   6  76  2.46
# 72     0 -0.94  0.60  -1.82  2.20  1.56  8.97  1.41  0.53   7  77  2.47
# 73     0 -1.52  0.50  -3.19  2.28  2.13  8.96  1.36  0.51   9  78  2.12
# 74     0 -3.33  0.50  -1.24  2.54  2.31  9.23  1.36  0.49  10  79  2.51
#
# [75 rows x 12 columns]

# %% [markdown]
# 여기서부터 Supervised Learning Part (SVM, Randomforest, NN)
#
# Training set 나누기!

# %%
x = data_cleaned.astype(float)
y = raw_data.iloc[:,1].astype(float)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=42)  # 적당한 비율로 training과 test set을 나누는 부분

# %% [markdown]
# # SVM

# %%
fs = 30
fs1 = 18

# %%
pipe = Pipeline([
    ('scaler', StandardScaler()),  # 표준화 단계
    ('svm', SVR(kernel='rbf'))  # SVM 단계
])

param_dist = {
    'svm__C': np.exp(norm(loc=0, scale=1).rvs(1000)),  # C 매개변수
    'svm__gamma': np.exp(norm(loc=0, scale=1).rvs(1000)),  # gamma 매개변수
}

# 무작위 검색 설정
svr_rnd_search = RandomizedSearchCV(pipe, param_distributions=param_dist, n_iter=100, cv=5, n_jobs=-1, scoring='neg_mean_squared_error',)

# %%
svr_rnd_search.fit(x_train, y_train)
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                              ('svm', SVR())]),
#                    n_iter=100, n_jobs=-1,
#                    param_distributions={'svm__C': array([ 0.86403328,  2.29183579,  2.70926403,  0.21356714,  0.73855459,
#         0.33336459,  2.77127171,  3.6540677 ,  1.53419156,  2.60235336,
#         1.41152677,  0.29340093,  2.25636159,  0.9064861 ,  1.47427311,
#         2.30197593,  0.97078513,  0.89948561,  1....
#         1.52733394,  0.86319426,  0.71866284,  0.38197656,  1.0099897 ,
#         1.06714781,  4.06469923,  0.61245497,  0.27429756, 11.44280868,
#         1.72206311,  0.79214055,  2.621519  ,  0.82855596,  0.55658787,
#         1.1856607 ,  0.70669082,  0.42480205,  0.84925913,  0.97632209,
#         1.5817544 ,  0.81669468,  1.2203591 ,  7.29474123,  1.37968436,
#         0.51571636,  1.43304315, 11.73980715,  8.47113162,  0.23644166])},
#                    scoring='neg_mean_squared_error')

# %%
print('Best Estimator ', svr_rnd_search.best_estimator_) # 위의 radomized search로 최고의 hyperparameter를 찾음!

print('Score on training set: ', svr_rnd_search.best_estimator_.score(x_train, y_train))
print('Score on test set: ', svr_rnd_search.best_estimator_.score(x_test, y_test))
# Out:
# Best Estimator  Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm', SVR(C=5.695505934482344, gamma=0.11412442837528598))])
# Score on training set:  0.9837884013372306
# Score on test set:  0.866071141100222

# %%
predict_svr_train = svr_rnd_search.best_estimator_.predict(x_train) # x_train를 넣어본 output
predict_svr = svr_rnd_search.best_estimator_.predict(x_test) # x_test를 넣어본 output

# %%
plt.figure(figsize=(12,9))

plt.scatter(y_test, predict_svr, color = 'r', s=150) # y_test가 real value, predic_svr이 학습한 data로 넣어본 value
plt.title('Support Vector Machine', fontsize=fs)
plt.xlabel('G_Cl, DFT (eV)', fontsize=fs)
plt.ylabel('G_Cl, ML (eV)', fontsize=fs)
plt.xticks(fontsize=fs1)
plt.yticks(fontsize=fs1)
plt.axis('equal')
plt.xlim(plt.xlim())
plt.ylim(plt.ylim())
plt.plot([-1000, 1000], [-1000,1000], linestyle='dashed');

# %% [markdown]
# # Random Forest

# %%
pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('rf', RandomForestRegressor())
])

# 파라미터 그리드 설정
param_grid = {
    'rf__n_estimators': randint(100, 500),  # 100에서 500 사이의 정수 랜덤 선택
    'rf__max_leaf_nodes': randint(10, 100)  # 10에서 100 사이의 정수 랜덤 선택
}

# 랜덤 서치 수행
rf_rnd_search = RandomizedSearchCV(
    estimator=pipeline,
    param_distributions=param_grid,
    n_iter=100,  # 100개의 랜덤한 조합 시도
    cv=5,  # 5-fold 교차 검증
    scoring='neg_mean_squared_error',
    random_state=42,
    n_jobs=-1
)

# 데이터에 대해 랜덤 서치 수행
rf_rnd_search.fit(x_train, y_train)
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                              ('rf', RandomForestRegressor())]),
#                    n_iter=100, n_jobs=-1,
#                    param_distributions={'rf__max_leaf_nodes': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000002001A82C050>,
#                                         'rf__n_estimators': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000002001A7DD290>},
#                    random_state=42, scoring='neg_mean_squared_error')

# %%
# 최적의 모델 및 파라미터 출력
print("Best Estimator:", rf_rnd_search.best_estimator_)

print('Score on training set:', rf_rnd_search.best_estimator_.score(x_train, y_train))
print('Score on test set:', rf_rnd_search.best_estimator_.score(x_test, y_test))
# Out:
# Best Estimator: Pipeline(steps=[('scaler', StandardScaler()),
#                 ('rf',
#                  RandomForestRegressor(max_leaf_nodes=95, n_estimators=134))])
# Score on training set: 0.9931996340030153
# Score on test set: 0.9260185379253478

# %%
predict_rf_train = rf_rnd_search.best_estimator_.predict(x_train) # 최고의 개수로 학습한 거에 x_train을 넣은 결과
predict_rf = rf_rnd_search.best_estimator_.predict(x_test) # 최고의 개수로 학습한 거에 x_test를 넣은 결과

# %%
plt.figure(figsize=(12,9))
plt.scatter(y_test, predict_rf, color='r', s=150) # pairity plot 그리기!!
plt.title('Random Forests', fontsize=fs)
plt.xlabel('G_Cl, DFT (eV)', fontsize=fs)
plt.ylabel('G_Cl, ML (eV)', fontsize=fs)
plt.xticks(fontsize=fs1)
plt.yticks(fontsize=fs1)
plt.axis('equal')
plt.xlim(plt.xlim())
plt.ylim(plt.ylim())
plt.plot([-1000, 1000], [-1000, 1000], linestyle='dashed');

# %% [markdown]
# # Neural Network

# %%
def build_model(n_hidden=1, n_neurons=30):
    model = Sequential()
    model.add(Dense(n_neurons, activation="relu", kernel_initializer="he_normal", input_shape=x_train.shape[1:]))
    for _ in range(n_hidden):
        model.add(Dense(n_neurons, activation="relu", kernel_initializer="he_normal"))
        model.add(BatchNormalization())
    model.add(Dense(1))
    model.compile(loss="mse", optimizer=Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999))
    return model

keras_reg = KerasRegressor(build_model)

param_distribs = {
    "kerasregressor__n_hidden": [0, 1, 2, 3],
    "kerasregressor__n_neurons": np.arange(1, 150),
}

pipeline = Pipeline([
    ("std_scaler", StandardScaler()),
    ("kerasregressor", keras_reg)
])

nn_rnd_search = RandomizedSearchCV(pipeline, param_distribs, n_iter=100, cv=5, n_jobs=-1)

nn_rnd_search.fit(x_train, y_train, kerasregressor__epochs=100)

print("Best parameters: ", nn_rnd_search.best_params_)
# Out:
# C:\Users\dino3\AppData\Local\Temp\ipykernel_24412\2026098280.py:11: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   keras_reg = KerasRegressor(build_model)
# C:\Users\dino3\AppData\Local\Programs\Python\Python311\Lib\site-packages\joblib\externals\loky\process_executor.py:700: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Epoch 1/100
# 2/2 [==============================] - 0s 5ms/step - loss: 1.6719
# Epoch 2/100
# 2/2 [==============================] - 0s 2ms/step - loss: 1.4805
# Epoch 3/100
# 2/2 [==============================] - 0s 2ms/step - loss: 1.3373
# Epoch 4/100
# 2/2 [==============================] - 0s 3ms/step - loss: 1.1886
# Epoch 5/100
# 2/2 [==============================] - 0s 2ms/step - loss: 1.0800
# Epoch 6/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.9779
# Epoch 7/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.8865
# Epoch 8/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.8001
# Epoch 9/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.7293
# Epoch 10/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.6648
# Epoch 11/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.6074
# Epoch 12/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.5593
# Epoch 13/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.5170
# Epoch 14/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.4811
# Epoch 15/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.4494
# Epoch 16/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.4171
# Epoch 17/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3930
# Epoch 18/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3685
# Epoch 19/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3449
# Epoch 20/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.3243
# Epoch 21/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.3068
# Epoch 22/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2874
# Epoch 23/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2708
# Epoch 24/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2541
# Epoch 25/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2388
# Epoch 26/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2259
# Epoch 27/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2120
# Epoch 28/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.1993
# Epoch 29/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.1877
# Epoch 30/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.1760
# Epoch 31/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.1665
# Epoch 32/100
# 2/2 [==============================] - 0s 1ms/step - loss: 0.1572
# Epoch 33/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.1479
# Epoch 34/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.1399
# Epoch 35/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.1318
# Epoch 36/100
# 2/2 [==============================] - 0s 1ms/step - loss: 0.1251
# Epoch 37/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1187
# Epoch 38/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.1124
# Epoch 39/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.1062
# Epoch 40/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.1014
# Epoch 41/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0961
# Epoch 42/100
# 2/2 [==============================] - 0s 999us/step - loss: 0.0914
# Epoch 43/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0872
# Epoch 44/100
# 2/2 [==============================] - 0s 1ms/step - loss: 0.0833
# Epoch 45/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0791
# Epoch 46/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0759
# Epoch 47/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0728
# Epoch 48/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0695
# Epoch 49/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0668
# Epoch 50/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0641
# Epoch 51/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0614
# Epoch 52/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0592
# Epoch 53/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0572
# Epoch 54/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0552
# Epoch 55/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0530
# Epoch 56/100
# 2/2 [==============================] - 0s 999us/step - loss: 0.0515
# Epoch 57/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0498
# Epoch 58/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0483
# Epoch 59/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0469
# Epoch 60/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0453
# Epoch 61/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0442
# Epoch 62/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0430
# Epoch 63/100
# 2/2 [==============================] - 0s 1000us/step - loss: 0.0419
# Epoch 64/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0407
# Epoch 65/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0399
# Epoch 66/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0389
# Epoch 67/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0381
# Epoch 68/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0373
# Epoch 69/100
# 2/2 [==============================] - 0s 1ms/step - loss: 0.0365
# Epoch 70/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0358
# Epoch 71/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0350
# Epoch 72/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0345
# Epoch 73/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0338
# Epoch 74/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0332
# Epoch 75/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0327
# Epoch 76/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0322
# Epoch 77/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0316
# Epoch 78/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0312
# Epoch 79/100
# 2/2 [==============================] - 0s 1000us/step - loss: 0.0307
# Epoch 80/100
# 2/2 [==============================] - 0s 1ms/step - loss: 0.0303
# Epoch 81/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0299
# Epoch 82/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0295
# Epoch 83/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0291
# Epoch 84/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0288
# Epoch 85/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0284
# Epoch 86/100
# 2/2 [==============================] - 0s 1ms/step - loss: 0.0281
# Epoch 87/100
# 2/2 [==============================] - 0s 999us/step - loss: 0.0277
# Epoch 88/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0274
# Epoch 89/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0272
# Epoch 90/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0269
# Epoch 91/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0266
# Epoch 92/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0263
# Epoch 93/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0261
# Epoch 94/100
# 2/2 [==============================] - 0s 999us/step - loss: 0.0260
# Epoch 95/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0257
# Epoch 96/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0254
# Epoch 97/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0252
# Epoch 98/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0249
# Epoch 99/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0247
# Epoch 100/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0245
# Best parameters:  {'kerasregressor__n_neurons': 88, 'kerasregressor__n_hidden': 0}

# %%
for i in range(len(nn_rnd_search.cv_results_['params'])):
    print("Parameters: ", nn_rnd_search.cv_results_['params'][i])
    print("Mean Test Score: ", nn_rnd_search.cv_results_['mean_test_score'][i])
    print("Rank: ", nn_rnd_search.cv_results_['rank_test_score'][i])
    print()
# Out:
# Parameters:  {'kerasregressor__n_neurons': 66, 'kerasregressor__n_hidden': 1}
# Mean Test Score:  -0.220523202419281
# Rank:  38
#
# Parameters:  {'kerasregressor__n_neurons': 24, 'kerasregressor__n_hidden': 1}
# Mean Test Score:  -0.2790254384279251
# Rank:  64
#
# Parameters:  {'kerasregressor__n_neurons': 39, 'kerasregressor__n_hidden': 0}
# Mean Test Score:  -0.20505614578723907
# Rank:  34
#
# Parameters:  {'kerasregressor__n_neurons': 133, 'kerasregressor__n_hidden': 0}
# Mean Test Score:  -0.14813096225261688
# Rank:  15
#
# Parameters:  {'kerasregressor__n_neurons': 95, 'kerasregressor__n_hidden': 0}
# Mean Test Score:  -0.18026835471391678
# Rank:  25
#
# Parameters:  {'kerasregressor__n_neurons': 68, 'kerasregressor__n_hidden': 2}
# Mean Test Score:  -0.28124541938304903
# Rank:  66
#
# Parameters:  {'kerasregressor__n_neurons': 83, 'kerasregressor__n_hidden': 2}
# Mean Test Score:  -0.24901123493909835
# Rank:  54
#
# Parameters:  {'kerasregressor__n_neurons': 49, 'kerasregressor__n_hidden': 2}
# Mean Test Score:  -0.20559066534042358
# Rank:  35
#
# Parameters:  {'kerasregressor__n_neurons': 20, 'kerasregressor__n_hidden': 2}
# Mean Test Score:  -0.5205823749303817
# Rank:  95
#
# Parameters:  {'kerasregressor__n_neurons': 44, 'kerasregressor__n_hidden': 3}
# Mean Test Score:  -0.1734050691127777
# Rank:  22
#
# Parameters:  {'kerasregressor__n_neurons': 123, 'kerasregressor__n_hidden': 3}
# Mean Test Score:  -0.32821476012468337
# Rank:  80
#
# Parameters:  {'kerasregressor__n_neurons': 144, 'kerasregressor__n_hidden': 2}
# Mean Test Score:  -0.2036903828382492
# Rank:  33
#
# Parameters:  {'kerasregressor__n_neurons': 79, 'kerasregressor__n_hidden': 1}
# Mean Test Score:  -0.2324037402868271
# Rank:  48
#
# Parameters:  {'kerasregressor__n_neurons': 81, 'kerasregressor__n_hidden': 1}
# Mean Test Score:  -0.13072427362203598
# Rank:  11
#
# Parameters:  {'kerasregressor__n_neurons': 122, 'kerasregressor__n_hidden': 0}
# Mean Test Score:  -0.08482947200536728
# Rank:  2
#
# Parameters:  {'kerasregressor__n_neurons': 23, 'kerasregressor__n_hidden': 2}
# Mean Test Score:  -0.35848383605480194
# Rank:  82
#
# Parameters:  {'kerasregressor__n_neurons': 122, 'kerasregressor__n_hidden': 1}
# Mean Test Score:  -0.2115742087364197
# Rank:  36
#
# Parameters:  {'kerasregressor__n_neurons': 90, 'kerasregressor__n_hidden': 1}
# Mean Test Score:  -0.40143515169620514
# Rank:  89
#
# Parameters:  {'kerasregressor__n_neurons': 84, 'kerasregressor__n_hidden': 1}
# Mean Test Score:  -0.22856295257806777
# Rank:  46
#
# Parameters:  {'kerasregressor__n_neurons': 134, 'kerasregressor__n_hidden': 0}
# Mean Test Score:  -0.086704570800066
# Rank:  3
#
# Parameters:  {'kerasregressor__n_neurons': 8, 'kerasregressor__n_hidden': 2}
# Mean Test Score:  -0.45414483547210693
# Rank:  94
#
# Parameters:  {'kerasregressor__n_neurons': 100, 'kerasregressor__n_hidden': 3}
# Mean Test Score:  -0.16326127871870993
# Rank:  21
#
# Parameters:  {'kerasregressor__n_neurons': 80, 'kerasregressor__n_hidden': 2}
# Mean Test Score:  -0.23024621605873108
# Rank:  47
#
# Parameters:  {'kerasregressor__n_neurons': 79, 'kerasregressor__n_hidden': 2}
# Mean Test Score:  -0.24162911474704743
# Rank:  50
#
# Parameters:  {'kerasregressor__n_neurons': 17, 'kerasregressor__n_hidden': 0}
# Mean Test Score:  -0.31832761168479917
# Rank:  77
#
# Parameters:  {'kerasregressor__n_neurons': 29, 'kerasregressor__n_hidden': 3}
# Mean Test Score:  -0.32273650020360944
# Rank:  78
#
# Parameters:  {'kerasregressor__n_neurons': 34, 'kerasregressor__n_hidden': 3}
# Mean Test Score:  -0.38763928711414336
# Rank:  87
#
# Parameters:  {'kerasregressor__n_neurons': 88, 'kerasregressor__n_hidden': 0}
# Mean Test Score:  -0.08176645860075951
# Rank:  1
#
# Parameters:  {'kerasregressor__n_neurons': 138, 'kerasregressor__n_hidden': 2}
# Mean Test Score:  -0.2895238369703293
# Rank:  69
#
# Parameters:  {'kerasregressor__n_neurons': 129, 'kerasregressor__n_hidden': 3}
# Mean Test Score:  -0.29899423718452456
# Rank:  72
#
# Parameters:  {'kerasregressor__n_neurons': 62, 'kerasregressor__n_hidden': 0}
# Mean Test Score:  -0.2500807672739029
# Rank:  55
#
# Parameters:  {'kerasregressor__n_neurons': 63, 'kerasregressor__n_hidden': 1}
# Mean Test Score:  -0.2699084848165512
# Rank:  60
#
# Parameters:  {'kerasregressor__n_neurons': 18, 'kerasregressor__n_hidden': 3}
# Mean Test Score:  -0.5307372868061065
# Rank:  96
#
# Parameters:  {'kerasregressor__n_neurons': 31, 'kerasregressor__n_hidden': 3}
# Mean Test Score:  -0.36183778643608094
# Rank:  83
#
# Parameters:  {'kerasregressor__n_neurons': 116, 'kerasregressor__n_hidden': 2}
# Mean Test Score:  -0.3869206413626671
# Rank:  86
#
# Parameters:  {'kerasregressor__n_neurons': 29, 'kerasregressor__n_hidden': 2}
# Mean Test Score:  -0.3945897400379181
# Rank:  88
#
# Parameters:  {'kerasregressor__n_neurons': 12, 'kerasregressor__n_hidden': 3}
# Mean Test Score:  -0.4308315455913544
# Rank:  92
#
# Parameters:  {'kerasregressor__n_neurons': 26, 'kerasregressor__n_hidden': 3}
# Mean Test Score:  -0.4287890374660492
# Rank:  91
#
# Parameters:  {'kerasregressor__n_neurons': 118, 'kerasregressor__n_hidden': 3}
# Mean Test Score:  -0.19267831444740297
# Rank:  31
#
# Parameters:  {'kerasregressor__n_neurons': 66, 'kerasregressor__n_hidden': 2}
# Mean Test Score:  -0.2732594579458237
# Rank:  61
#
# Parameters:  {'kerasregressor__n_neurons': 84, 'kerasregressor__n_hidden': 3}
# Mean Test Score:  -0.2232498824596405
# Rank:  44
#
# Parameters:  {'kerasregressor__n_neurons': 67, 'kerasregressor__n_hidden': 1}
# Mean Test Score:  -0.19114948064088821
# Rank:  30
#
# Parameters:  {'kerasregressor__n_neurons': 130, 'kerasregressor__n_hidden': 1}
# Mean Test Score:  -0.2206173449754715
# Rank:  40
#
# Parameters:  {'kerasregressor__n_neurons': 25, 'kerasregressor__n_hidden': 3}
# Mean Test Score:  -0.3490749210119247
# Rank:  81
#
# Parameters:  {'kerasregressor__n_neurons': 89, 'kerasregressor__n_hidden': 1}
# Mean Test Score:  -0.28317690044641497
# Rank:  67
#
# Parameters:  {'kerasregressor__n_neurons': 54, 'kerasregressor__n_hidden': 0}
# Mean Test Score:  -0.15759498178958892
# Rank:  20
#
# Parameters:  {'kerasregressor__n_neurons': 3, 'kerasregressor__n_hidden': 1}
# Mean Test Score:  -1.0681570589542388
# Rank:  99
#
# Parameters:  {'kerasregressor__n_neurons': 104, 'kerasregressor__n_hidden': 3}
# Mean Test Score:  -0.2779895454645157
# Rank:  63
#
# Parameters:  {'kerasregressor__n_neurons': 27, 'kerasregressor__n_hidden': 1}
# Mean Test Score:  -0.22212523967027664
# Rank:  42
#
# Parameters:  {'kerasregressor__n_neurons': 67, 'kerasregressor__n_hidden': 2}
# Mean Test Score:  -0.2232479840517044
# Rank:  43
#
# Parameters:  {'kerasregressor__n_neurons': 73, 'kerasregressor__n_hidden': 3}
# Mean Test Score:  -0.18288853764533997
# Rank:  26
#
# Parameters:  {'kerasregressor__n_neurons': 147, 'kerasregressor__n_hidden': 3}
# Mean Test Score:  -0.14866740852594376
# Rank:  16
#
# Parameters:  {'kerasregressor__n_neurons': 124, 'kerasregressor__n_hidden': 1}
# Mean Test Score:  -0.185356305539608
# Rank:  27
#
# Parameters:  {'kerasregressor__n_neurons': 125, 'kerasregressor__n_hidden': 1}
# Mean Test Score:  -0.21941746771335602
# Rank:  37
#
# Parameters:  {'kerasregressor__n_neurons': 72, 'kerasregressor__n_hidden': 3}
# Mean Test Score:  -0.29983340948820114
# Rank:  73
#
# Parameters:  {'kerasregressor__n_neurons': 23, 'kerasregressor__n_hidden': 0}
# Mean Test Score:  -0.2588075056672096
# Rank:  57
#
# Parameters:  {'kerasregressor__n_neurons': 124, 'kerasregressor__n_hidden': 0}
# Mean Test Score:  -0.14764281287789344
# Rank:  14
#
# Parameters:  {'kerasregressor__n_neurons': 115, 'kerasregressor__n_hidden': 1}
# Mean Test Score:  -0.15353741198778154
# Rank:  17
#
# Parameters:  {'kerasregressor__n_neurons': 49, 'kerasregressor__n_hidden': 1}
# Mean Test Score:  -0.17423016726970672
# Rank:  23
#
# Parameters:  {'kerasregressor__n_neurons': 84, 'kerasregressor__n_hidden': 0}
# Mean Test Score:  -0.1061832707375288
# Rank:  5
#
# Parameters:  {'kerasregressor__n_neurons': 140, 'kerasregressor__n_hidden': 0}
# Mean Test Score:  -0.13554290533065796
# Rank:  12
#
# Parameters:  {'kerasregressor__n_neurons': 149, 'kerasregressor__n_hidden': 0}
# Mean Test Score:  -0.11513774320483208
# Rank:  9
#
# Parameters:  {'kerasregressor__n_neurons': 6, 'kerasregressor__n_hidden': 3}
# Mean Test Score:  -0.6646924078464508
# Rank:  98
#
# Parameters:  {'kerasregressor__n_neurons': 17, 'kerasregressor__n_hidden': 1}
# Mean Test Score:  -0.37032258212566377
# Rank:  84
#
# Parameters:  {'kerasregressor__n_neurons': 139, 'kerasregressor__n_hidden': 2}
# Mean Test Score:  -0.32567424774169923
# Rank:  79
#
# Parameters:  {'kerasregressor__n_neurons': 97, 'kerasregressor__n_hidden': 0}
# Mean Test Score:  -0.10342006757855415
# Rank:  4
#
# Parameters:  {'kerasregressor__n_neurons': 126, 'kerasregressor__n_hidden': 0}
# Mean Test Score:  -0.11052953638136387
# Rank:  7
#
# Parameters:  {'kerasregressor__n_neurons': 126, 'kerasregressor__n_hidden': 1}
# Mean Test Score:  -0.15532422959804534
# Rank:  18
#
# Parameters:  {'kerasregressor__n_neurons': 45, 'kerasregressor__n_hidden': 1}
# Mean Test Score:  -0.18734948784112931
# Rank:  29
#
# Parameters:  {'kerasregressor__n_neurons': 143, 'kerasregressor__n_hidden': 2}
# Mean Test Score:  -0.18013855069875717
# Rank:  24
#
# Parameters:  {'kerasregressor__n_neurons': 86, 'kerasregressor__n_hidden': 3}
# Mean Test Score:  -0.22059567272663116
# Rank:  39
#
# Parameters:  {'kerasregressor__n_neurons': 42, 'kerasregressor__n_hidden': 0}
# Mean Test Score:  -0.29456397965550424
# Rank:  71
#
# Parameters:  {'kerasregressor__n_neurons': 146, 'kerasregressor__n_hidden': 3}
# Mean Test Score:  -0.2217850536108017
# Rank:  41
#
# Parameters:  {'kerasregressor__n_neurons': 71, 'kerasregressor__n_hidden': 1}
# Mean Test Score:  -0.2430317297577858
# Rank:  51
#
# Parameters:  {'kerasregressor__n_neurons': 62, 'kerasregressor__n_hidden': 3}
# Mean Test Score:  -0.2758779376745224
# Rank:  62
#
# Parameters:  {'kerasregressor__n_neurons': 114, 'kerasregressor__n_hidden': 0}
# Mean Test Score:  -0.14235785007476806
# Rank:  13
#
# Parameters:  {'kerasregressor__n_neurons': 37, 'kerasregressor__n_hidden': 3}
# Mean Test Score:  -0.28400037586689
# Rank:  68
#
# Parameters:  {'kerasregressor__n_neurons': 62, 'kerasregressor__n_hidden': 2}
# Mean Test Score:  -0.25506347715854644
# Rank:  56
#
# Parameters:  {'kerasregressor__n_neurons': 145, 'kerasregressor__n_hidden': 3}
# Mean Test Score:  -0.30159332454204557
# Rank:  74
#
# Parameters:  {'kerasregressor__n_neurons': 94, 'kerasregressor__n_hidden': 1}
# Mean Test Score:  -0.291284915804863
# Rank:  70
#
# Parameters:  {'kerasregressor__n_neurons': 90, 'kerasregressor__n_hidden': 0}
# Mean Test Score:  -0.15607993304729462
# Rank:  19
#
# Parameters:  {'kerasregressor__n_neurons': 5, 'kerasregressor__n_hidden': 3}
# Mean Test Score:  -1.2279578626155854
# Rank:  100
#
# Parameters:  {'kerasregressor__n_neurons': 111, 'kerasregressor__n_hidden': 2}
# Mean Test Score:  -0.2431494653224945
# Rank:  52
#
# Parameters:  {'kerasregressor__n_neurons': 109, 'kerasregressor__n_hidden': 0}
# Mean Test Score:  -0.10710030347108841
# Rank:  6
#
# Parameters:  {'kerasregressor__n_neurons': 27, 'kerasregressor__n_hidden': 3}
# Mean Test Score:  -0.44515022039413454
# Rank:  93
#
# Parameters:  {'kerasregressor__n_neurons': 41, 'kerasregressor__n_hidden': 2}
# Mean Test Score:  -0.5447222709655761
# Rank:  97
#
# Parameters:  {'kerasregressor__n_neurons': 87, 'kerasregressor__n_hidden': 2}
# Mean Test Score:  -0.2600082516670227
# Rank:  58
#
# Parameters:  {'kerasregressor__n_neurons': 33, 'kerasregressor__n_hidden': 1}
# Mean Test Score:  -0.3156231179833412
# Rank:  76
#
# Parameters:  {'kerasregressor__n_neurons': 32, 'kerasregressor__n_hidden': 3}
# Mean Test Score:  -0.2796993240714073
# Rank:  65
#
# Parameters:  {'kerasregressor__n_neurons': 98, 'kerasregressor__n_hidden': 0}
# Mean Test Score:  -0.11240016780793667
# Rank:  8
#
# Parameters:  {'kerasregressor__n_neurons': 105, 'kerasregressor__n_hidden': 1}
# Mean Test Score:  -0.2392229214310646
# Rank:  49
#
# Parameters:  {'kerasregressor__n_neurons': 111, 'kerasregressor__n_hidden': 0}
# Mean Test Score:  -0.12847751379013062
# Rank:  10
#
# Parameters:  {'kerasregressor__n_neurons': 94, 'kerasregressor__n_hidden': 3}
# Mean Test Score:  -0.24740594178438186
# Rank:  53
#
# Parameters:  {'kerasregressor__n_neurons': 104, 'kerasregressor__n_hidden': 2}
# Mean Test Score:  -0.18587238043546678
# Rank:  28
#
# Parameters:  {'kerasregressor__n_neurons': 129, 'kerasregressor__n_hidden': 2}
# Mean Test Score:  -0.2691106304526329
# Rank:  59
#
# Parameters:  {'kerasregressor__n_neurons': 10, 'kerasregressor__n_hidden': 2}
# Mean Test Score:  -0.4078056991100311
# Rank:  90
#
# Parameters:  {'kerasregressor__n_neurons': 134, 'kerasregressor__n_hidden': 3}
# Mean Test Score:  -0.3138554453849792
# Rank:  75
#
# Parameters:  {'kerasregressor__n_neurons': 116, 'kerasregressor__n_hidden': 3}
# Mean Test Score:  -0.20006278306245803
# Rank:  32
#
# Parameters:  {'kerasregressor__n_neurons': 16, 'kerasregressor__n_hidden': 3}
# Mean Test Score:  -0.38289842307567595
# Rank:  85
#
# Parameters:  {'kerasregressor__n_neurons': 132, 'kerasregressor__n_hidden': 2}
# Mean Test Score:  -0.22645257115364076
# Rank:  45

# %%
# 최고의 모델 가져오기
best_model = nn_rnd_search.best_estimator_

# train set 예측 및 R^2 score 계산
predict_nn_train = best_model.predict(x_train)
train_r2 = r2_score(y_train, predict_nn_train)

# test set 예측 및 R^2 score 계산
predict_nn = best_model.predict(x_test)
test_r2 = r2_score(y_test, predict_nn)

print("Train set R^2 score:", train_r2)
print("Test set R^2 score:", test_r2)
# Out:
# 2/2 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# Train set R^2 score: 0.981321182870095
# Test set R^2 score: 0.9127595641421956

# %%
plt.figure(figsize=(12,9))
plt.scatter(y_test, predict_nn, color ='r', s = 150)
plt.title('Neural Network', fontsize=fs)
plt.xlabel('G_Cl, DFT (eV)', fontsize=fs)
plt.ylabel('G_Cl, ML (eV)', fontsize=fs)
plt.xticks(fontsize=fs1)
plt.yticks(fontsize=fs1)
plt.axis('equal')
plt.xlim(plt.xlim())
plt.ylim(plt.ylim())
plt.plot([-1000, 1000], [-1000,1000], linestyle='dashed');

# %% [markdown]
# # 3개 Model의 성능 비교

# %%
mse_svr_train = mean_squared_error(y_train, predict_svr_train) # svr에서 train set 에러
mse_svr_test = mean_squared_error(y_test, predict_svr) # svr에서 test set 에러

mse_rf_train = mean_squared_error(y_train, predict_rf_train) # rdf에서 train set 에러
mse_rf_test = mean_squared_error(y_test, predict_rf) # rdf에서 test set 에러

mse_nn_train = mean_squared_error(y_train, predict_nn_train) # svr에서 train set 에러
mse_nn_test = mean_squared_error(y_test, predict_nn) # svr에서 test set 에러

print('SVM MSE: ', mse_svr_test)
print('Random Forest MSE: ', mse_rf_test)
print('NN MSE: ', mse_nn_test)

r2_svr_train = r2_score(y_train, predict_svr_train) # svr에서 train set r2 점수
r2_svr_test = r2_score(y_test, predict_svr) # svr에서 test set r2 점수

r2_rf_train = r2_score(y_train, predict_rf_train) # rdf에서 train set r2 점수
r2_rf_test = r2_score(y_test, predict_rf) # rdf에서 test set r2 점수

r2_nn_train = r2_score(y_train, predict_nn_train) # svr에서 train set r2 점수
r2_nn_test = r2_score(y_test, predict_nn) # svr에서 test set r2 점수

print('SVM R^2: ', r2_svr_test)
print('Random Forest R^2: ', r2_rf_test)
print('NN R^2: ', r2_nn_test)
# Out:
# SVM MSE:  0.13846636957648928
# Random Forest MSE:  0.07648795452743741
# NN MSE:  0.09019614243514447
# SVM R^2:  0.866071141100222
# Random Forest R^2:  0.9260185379253478
# NN R^2:  0.9127595641421956

# %%
svr = mpatches.Patch(color='m', label='Support Vector Regression')
rf = mpatches.Patch(color='k', label='Random Forests')
nn = mpatches.Patch(color='g', label='Neural Nets')

names = ['train', 'test', 'train', 'test', 'train', 'test']
pos = range(len(names))
colors = ['m', 'm', 'k', 'k', 'g', 'g']
rotation = 0

plt.figure(figsize=(18,9))
plt.suptitle('Overall metrics', y=1.02)
plt.subplot(121)
plt.bar(pos, [mse_svr_train, mse_svr_test, mse_rf_train, mse_rf_test, mse_nn_train, mse_nn_test], color=colors)
plt.xticks(pos, names, rotation=rotation)
plt.ylabel('mean squared error')

plt.subplot(122)
plt.bar(pos, [r2_svr_train, r2_svr_test, r2_rf_train, r2_rf_test, r2_nn_train, r2_nn_test], color=colors)
plt.xticks(pos, names, rotation=rotation)
plt.ylabel('R2 score')

plt.tight_layout()
plt.legend(loc='upper center', handles=[svr, rf, nn], ncol=3, bbox_to_anchor=(-0.1, -0.05));

# %% [markdown]
# # Feature Importance Search

# %% [markdown]
# ### 1. RandomForest 기반 Feature importance

# %%
print("Best Estimator:", rf_rnd_search.best_estimator_)
# Out:
# Best Estimator: Pipeline(steps=[('scaler', StandardScaler()),
#                 ('rf',
#                  RandomForestRegressor(max_leaf_nodes=95, n_estimators=134))])

# %%
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)

# %%
best_params = rf_rnd_search.best_params_

max_leaf_nodes = best_params['rf__max_leaf_nodes']
n_estimators = best_params['rf__n_estimators']

regressor = RandomForestRegressor(n_estimators=n_estimators, max_leaf_nodes=max_leaf_nodes)

select_features = SelectFromModel(regressor)
# 앞에서 구한 최고의 parameter 사용
select_features.fit(x_train_scaled, y_train)
selected_features = x_train.columns[(select_features.get_support())] # 가장 중요한 feature들을 알려줌!

print(selected_features)
# Out:
# Index(['ed', 'rcov', 'Ne'], dtype='object')

# %%
regressor.fit(x_train_scaled, y_train)
sort = regressor.feature_importances_.argsort()
plt.barh(feature_names[sort], regressor.feature_importances_[sort])
plt.xlabel("Feature Importance", fontsize='20')
# Out:
# Text(0.5, 0, 'Feature Importance')

# %% [markdown]
# ### 2. Ridge 기반 Feature importance

# %%
model = make_pipeline(StandardScaler(), RidgeCV())

model.fit(x_train, y_train)

print(f'model score on training data: {model.score(x_train, y_train)}')
print(f'model score on testing data: {model.score(x_test, y_test)}')
# Out:
# model score on training data: 0.9251639559765392
# model score on testing data: 0.8995196534850398

# %%
coefs = pd.DataFrame(
   model[1].coef_,
   columns=['Coefficients'], index=x_train.columns
)

coefs.plot(kind='barh', figsize=(9, 7))
plt.title('Ridge model')
plt.axvline(x=0, color='.5')
plt.subplots_adjust(left=.3)

# %%
cv_model = cross_validate(
   model, x, y, cv=RepeatedKFold(n_splits=5, n_repeats=5),
   return_estimator=True, n_jobs=2
)
coefs = pd.DataFrame(
   [model[1].coef_
    for model in cv_model['estimator']],
   columns=x.columns
)
plt.figure(figsize=(9, 7))
sns.boxplot(data=coefs, orient='h', color='cyan', saturation=0.5)
plt.axvline(x=0, color='.5')
plt.xlabel('Coefficient importance')
plt.title('Coefficient importance and its variability')
plt.subplots_adjust(left=.3)

# %% [markdown]
# ### 3. Lasso 기반 Feautre importance

# %%
model = make_pipeline(StandardScaler(), Lasso(alpha=.015))

model.fit(x_train, y_train)

print(f'model score on training data: {model.score(x_train, y_train)}')
print(f'model score on testing data: {model.score(x_test, y_test)}')
# Out:
# model score on training data: 0.9205143909169117
# model score on testing data: 0.8887134259524362

# %%
coefs = pd.DataFrame(
   model[1].coef_,
   columns=['Coefficients'], index=x_train.columns
)

coefs.plot(kind='barh', figsize=(9, 7))
plt.title('Lasso model, strong regularization')
plt.axvline(x=0, color='.5')
plt.subplots_adjust(left=.3)

# %%
cv_model = cross_validate(
   model, x, y, cv=RepeatedKFold(n_splits=5, n_repeats=5),
   return_estimator=True, n_jobs=2
)
coefs = pd.DataFrame(
   [model[1].coef_
    for model in cv_model['estimator']],
   columns=x.columns
)
plt.figure(figsize=(9, 7))
sns.boxplot(data=coefs, orient='h', color='cyan', saturation=0.5)
plt.axvline(x=0, color='.5')
plt.xlabel('Coefficient importance')
plt.title('Coefficient importance and its variability')
plt.subplots_adjust(left=.3)

# %% [markdown]
# ### 4. Permutation 기반 feature importance (random forest)

# %%
model = rf_rnd_search.best_estimator_

# %%
def get_score_after_permutation(model, X, y, curr_feat):
    """ return the score of model when curr_feat is permuted """

    X_permuted = X.copy()
    col_idx = list(X.columns).index(curr_feat)
    # permute one column
    X_permuted.iloc[:, col_idx] = np.random.permutation(
        X_permuted[curr_feat].values)

    permuted_score = model.score(X_permuted, y)
    return permuted_score


def get_feature_importance(model, X, y, curr_feat):
    """ compare the score when curr_feat is permuted """

    baseline_score_train = model.score(X, y)
    permuted_score_train = get_score_after_permutation(model, X, y, curr_feat)

    # feature importance is the difference between the two scores
    feature_importance = baseline_score_train - permuted_score_train
    return feature_importance

def permutation_importance(model, X, y, n_repeats=10):
    """Calculate importance score for each feature."""

    importances = []
    for curr_feat in X.columns:
        list_feature_importance = []
        for n_round in range(n_repeats):
            list_feature_importance.append(
                get_feature_importance(model, X, y, curr_feat))

        importances.append(list_feature_importance)

    return {'importances_mean': np.mean(importances, axis=1),
            'importances_std': np.std(importances, axis=1),
            'importances': importances}

def plot_feature_importances(perm_importance_result, feat_name):
    """ bar plot the feature importance """

    fig, ax = plt.subplots()

    indices = perm_importance_result['importances_mean'].argsort()
    plt.barh(range(len(indices)),
             perm_importance_result['importances_mean'][indices],
             xerr=perm_importance_result['importances_std'][indices])

    ax.set_yticks(range(len(indices)))
    _ = ax.set_yticklabels(feat_name[indices])

# %%
x_train_scaled_df = pd.DataFrame(x_train_scaled, columns=x_train.columns)

perm_importance_result_train = permutation_importance(
    model, x_train_scaled_df, y_train, n_repeats=10)

plot_feature_importances(perm_importance_result_train, x_train.columns)

# %% [markdown]
# # 상관계수 분석

# %%
def correlation_heatmap(train):
    correlations = train.corr()

    fig, ax = plt.subplots(figsize=(10,10))
    sns.heatmap(correlations, vmax=1.0, center=0, fmt='.2f', cmap="YlGnBu",
                square=True, linewidths=.5, annot=True, cbar_kws={"shrink": .70}
                )
    plt.show()

# %% [markdown]
# ## target value 넣어서 분석

# %%
corr = raw_data.iloc[:,1:]
feature_names_corr = np.array(['G_Cl','Nnum', 'ed', 'Qe', 'Ecohe', 'EN', 'EA', 'I', 'rcov', 'rZ', 'Ne', 'N', 'dMN'])

correlation_heatmap(corr[feature_names_corr])
